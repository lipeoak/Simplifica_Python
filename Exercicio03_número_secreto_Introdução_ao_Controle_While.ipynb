# %% [markdown]
# <a href="https://colab.research.google.com/github/lipeoak/Simplifica_Python/blob/main/Fundamentos_de_Python_Exercicio03_n%C3%BAmero_secreto_Introdu%C3%A7%C3%A3o_ao_Controle_While.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exemplo Prático - Resolução do aluno.
#
# Vamos criar um programa que pede ao usuário para adivinhar um número aleatório e fornece dicas sobre se o palpite é muito alto ou muito baixo. O loop while continuará até que o usuário adivinhe corretamente o número.

# %%
import random

numero_secreto = random.randint(1,100)
palpite = 0

print("Descubra o número secreto!!!")

while palpite != numero_secreto:
  palpite = int(input("Informe um número entre 1 e 100 para tentar acertar o número secreto: "))
  if palpite > numero_secreto:
    print(f"{palpite} é maior que o número secreto")
  elif palpite < numero_secreto:
    print(f'{palpite} é menor que o número secreto')
print(f'Você acertou o número secreto! O número secreto é: {palpite}')
# Out:
# Descubra o número secreto!!!
# Informe um número entre 1 e 100 para tentar acertar o número secreto: 50
# 50 é maior que o número secreto
# Informe um número entre 1 e 100 para tentar acertar o número secreto: 25
# 25 é maior que o número secreto
# Informe um número entre 1 e 100 para tentar acertar o número secreto: 12
# 12 é menor que o número secreto
# Informe um número entre 1 e 100 para tentar acertar o número secreto: 18
# 18 é maior que o número secreto
# Informe um número entre 1 e 100 para tentar acertar o número secreto: 15
# 15 é menor que o número secreto
# Informe um número entre 1 e 100 para tentar acertar o número secreto: 16
# Você acertou o número secreto! O número secreto é: 16

# %% [markdown]
# # Simplifica Python
# ---
# 🤖 **Estruturas de Controle (while)**
#
# A estrutura de controle **while** é utilizada para criar loops, ou seja, repetir um bloco de código enquanto uma condição específica for verdadeira.
#
# ![while.jpg](data:image/jpeg;base64,...)
#
#
# A sintaxe básica do loop while em Python é a seguinte:

# %%
while condição:
    # Código a ser executado enquanto a condição for verdadeira
    # ...

# %% [markdown]
# A condição é uma expressão booleana que é avaliada antes de cada iteração do loop. Enquanto a condição for verdadeira, o bloco de código dentro do loop é executado. Assim que a condição se torna falsa, a execução do loop é interrompida, e o programa continua com a próxima instrução após o loop.
#
# Aqui está um exemplo simples de um loop while que imprime os números de 1 a 5:

# %%
numero = 4

while numero <=5:
  print(numero)
  numero = numero +1

print("Terminou o programa")
# Out:
# 4
# 5
# Terminou o programa

# %% [markdown]
# Neste exemplo, o loop continuará a ser executado enquanto a variável contador for menor ou igual a 5. A cada iteração, o valor de contador é impresso e incrementado em 1. O loop será interrompido quando contador se tornar 6, pois a condição contador <= 5 se tornará falsa.
#
# É importante ter cuidado ao usar loops while para evitar loops infinitos. Certifique-se de que a condição do loop eventualmente se torne falsa para que o loop possa ser encerrado. Caso contrário, o programa ficará preso em um loop infinito, o que pode levar a problemas de desempenho e até mesmo à parada forçada do programa.

# %% [markdown]
# ---
# **2 - Exemplo Prático**
#
# Vamos criar um programa que pede ao usuário para adivinhar um número aleatório e fornece dicas sobre se o palpite é muito alto ou muito baixo. O loop while continuará até que o usuário adivinhe corretamente o número.

# %%
import random

numero_secreto = random.randint(1, 100)

print ("Bem-vindo ao programa ADIVINHA")
print ("Tente adivinhar o numero secreto")

palpite = 0

while palpite != numero_secreto:
  palpite = int(input("Digite o seu palpite:"))

  if palpite  > numero_secreto:
    print("Seu palpite está acima do numero secreto")
  elif palpite  < numero_secreto:
    print("Seu palpite está abaixo do numero secreto")
  else:
    print(f"Você acertou o numero secreto: {numero_secreto}")
# Out:
# Bem-vindo ao programa ADIVINHA
# Tente adivinhar o numero secreto
# Digite o seu palpite:50
# Seu palpite está acima do numero secreto
# Digite o seu palpite:25
# Seu palpite está abaixo do numero secreto
# Digite o seu palpite:37
# Seu palpite está acima do numero secreto
# Digite o seu palpite:32
# Seu palpite está abaixo do numero secreto
# Digite o seu palpite:34
# Seu palpite está abaixo do numero secreto
# Digite o seu palpite:35
# Você acertu o numero secreto: 35

# %% [markdown]
# Explicação:
#
# Neste exemplo, o programa gera um número secreto aleatório entre 1 e 100. O usuário é solicitado a fornecer palpites, e o programa fornece dicas sobre se o palpite é muito alto, muito baixo ou correto. O loop while continua até que o usuário adivinhe corretamente o número secreto. Este é um exemplo interativo e simples que pode ser atraente para os usuários, especialmente aqueles que estão aprendendo a programar em Python.

# %% [markdown]
# ---
#
# ✅ Se surgirem mais perguntas ou se precisarem de apoio em seus projetos, não hesitem em nos chamar. Estamos à disposição para oferecer assistência.
#
# [Simplifica Treinamentos](https://www.simplificatreinamentos.com.br/)
